# %% [markdown]
# ***
# # AirBNB Data Science
# ***

# %%
import numpy as np
import pandas as pd

# load dataset
df = pd.read_csv("airbnb_listings_zurich.csv")
display(df.head())
print(df.columns)
print("hello guys")
